# %% [markdown]
# ## **Question Answering with Llama 3.2 1B Model**

# %%
#load Model
import torch
from unsloth import FastLanguageModel
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-1B-Instruct-bnb-4bit",
    max_seq_length = 2048,
    dtype = None,
    load_in_4bit = True,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.2.12: Fast Llama patching. Transformers: 4.46.1.
#    \\   /|    GPU: NVIDIA GeForce RTX 4070 Ti SUPER. Max memory: 15.693 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.9. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
from unsloth.chat_templates import get_chat_template
import re
import base64
from PIL import Image
import io
import numpy as np
from torchvision import transforms

# set the model for inference
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
FastVisionModel.for_inference(modelV) # Enable for inference!

# Configure tokenizer with chat template
tokenizer = get_chat_template(
    tokenizer,
    chat_template="chatml",  # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, unsloth
    mapping={"role": "from", "content": "value", "user": "human", "assistant": "gpt"},  # ShareGPT style
    map_eos_token=True,  # Maps <|im_end|> to </s> instead
)

def get_summary(text):
    messages = [
        {"from": "system", "value": "You are a helpful AI assistant."},
        {"from": "human", "value": f"Summarize the following text: {text}"},
    ]
    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt",
    ).to("cuda")
    
    with torch.no_grad():
        outputs = model.generate(input_ids=inputs, max_new_tokens=512, use_cache=True)
        response = tokenizer.batch_decode(outputs)[0]
        
        # Extract the content after "<|im_start|>assistant" and before "<|im_end|>"
        pattern = r"<\|im_start\|>assistant\n(.*?)<\|im_end\|>"
        matches = re.search(pattern, response, re.DOTALL)
        
        if matches:
            return matches.group(1).strip()  # Extract matched content and remove extra spaces
        else:
            return None
            
def base64_to_tensor(base64_string):
    # Decode base64 string to bytes
    image_data = base64.b64decode(base64_string)
    # Convert bytes to image using PIL
    image = Image.open(io.BytesIO(image_data)).convert("RGB")  # Convert to RGB for LLaMA
    return image
    
def analyze_image(image_tensor):
    instruction = "Describe accurately and concisely what you see in this image."

    messages = [
        {"role": "user", "content": [
            {"type": "image"},
            {"type": "text", "text": instruction}
        ]}
    ]
    
    input_text = tokenizerV.apply_chat_template(messages, add_generation_prompt=True)
    
    inputs = tokenizerV(
        image_tensor,
        input_text,
        add_special_tokens=False,
        return_tensors="pt",
    ).to("cuda")

    # Remove TextStreamer, no longer necessary
    with torch.no_grad():
        outputs = modelV.generate(**inputs, max_new_tokens=300, temperature=0.5)
        response = tokenizerV.decode(outputs[0], skip_special_tokens=True)
    return response.split("assistant\n\n")[1].strip() if "assistant\n\n" in response else response
    
def summarize_row(row):
    if row["element_type"] == "text":
        return get_summary(row["content"])
    elif row["element_type"] == "image":
        return analyze_image(base64_to_tensor(row["content"]))
    else:
        return None
        
# ###--Uncomment for summarizing using llama----#####
# df["summary"] = df.apply(summarize_row, axis=1)
# df.to_parquet(os.path.join(output_dir, "extracted_data_summary_llama.parquet"), index=False)

# %%
# Load the Parquet file into a DataFrame
df = pd.read_parquet(os.path.join(output_dir, "extracted_data_summary_llama.parquet"))
# Check the loaded DataFrame
df
# Out:
#               pdf_name element_type  \
# 0     Sample_Table.pdf        table
# 1   chap_1_content.pdf         text
# 2   chap_1_content.pdf         text
# 3   chap_1_content.pdf         text
# 4   chap_1_content.pdf         text
# 5   chap_1_content.pdf         text
# 6   chap_1_content.pdf         text
# 7   chap_1_content.pdf         text
# 8   chap_1_content.pdf         text
# 9   chap_1_content.pdf         text
# 10  chap_1_content.pdf         text
# 11  chap_1_content.pdf         text
# 12  chap_1_content.pdf         text
# 13  chap_1_content.pdf         text
# 14  chap_1_content.pdf         text
# 15  chap_1_content.pdf        image
# 16  chap_1_content.pdf        image
# 17  chap_1_content.pdf        image
# 18  chap_1_content.pdf        image
# 19  chap_1_content.pdf        image
# 20  chap_1_content.pdf        image
# 21  chap_1_content.pdf        image
# 22  chap_1_content.pdf        image
# 23  chap_1_content.pdf        image
# 24  chap_1_content.pdf        image
# 25  chap_1_content.pdf        image
# 26  chap_1_content.pdf        image
# 27  chap_1_content.pdf        image
# 28  chap_1_content.pdf        image
# 29  chap_1_content.pdf        image
# 30  chap_1_content.pdf        image
# 31  chap_1_content.pdf        image
# 32  chap_1_content.pdf        image
# 33  chap_1_content.pdf        image
# 34  chap_1_content.pdf        image
# 35  chap_1_content.pdf        image
# 36  chap_1_content.pdf        image
# 37  chap_1_content.pdf        image
# 38  chap_1_content.pdf        image
# 39  chap_1_content.pdf        image
# 40  chap_1_content.pdf        image
# 41  chap_1_content.pdf        image
# 42  chap_1_content.pdf        image
# 43  chap_1_content.pdf        image
# 44  chap_1_content.pdf        image
# 45  chap_1_content.pdf        image
# 46  chap_1_content.pdf        image
# 47  chap_1_content.pdf        image
# 48  chap_1_content.pdf        image
# 49  chap_1_content.pdf        image
# 50  chap_1_content.pdf        image
# 51  chap_1_content.pdf        image
# 52  chap_1_content.pdf        image
# 53  chap_1_content.pdf        image
# 54  chap_1_content.pdf        image
#
#                                               content  \
# 0   gASV6wIAAAAAAAB9lCiMBHR5cGWUjAVUYWJsZZSMCmVsZW...
# 1   1 www.tntextbooks.in LAWS OF MOTION\n\nLearnin...
# 2   in this unit.\n\n1\n\n| | 10th_Science_Unit-1....
# 3   1 .2 .1 T ypes of I nertia\n\na) Inertia of re...
# 4   forces.\n\n(a) Like parallel forces: Two or mo...
# 5   1 .4 .5 Rotating Effect of Force\n\nThe door c...
# 6   1 .4 .7 Application of T orque\n\n1. Gears:\n\...
# 7   1 .5 NE W T ON’ S S E C OND L A W OF MOT I ON\...
# 8   1 .7 NE W T ON’ S T H I R D L A W OF MOT I ON\...
# 9   Figure 1.7 Conservation of\n\nlinear momentum\...
# 10  1 .9 R OC K E T P R OP UL S I ON\n\nPropulsion...
# 11  R2\n\nAcceleration due to gravity\n\ng = GM --...
# 12  the gravity.\n\nWeight = Gravitational Force\n...
# 13  1 .1 2 .2 W eightlessness of the astronauts\n\...
# 14  Solution: Linear momentum = mass × velocity\n\...
# 15  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 16  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 17  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 18  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 19  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 21  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 22  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 23  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 24  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 25  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 26  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 27  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 28  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 29  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 30  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 31  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 32  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 33  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 34  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 35  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 36  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 37  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 38  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 39  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 40  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 41  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 42  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 43  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 44  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 45  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 46  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 47  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 48  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 49  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 50  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 51  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 52  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 53  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 54  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                               summary
# 0                                                None
# 1   Here's a summary of the text:\n\nThe text disc...
# 2   The text describes the concepts of mechanics i...
# 3   The text appears to be a summary of concepts r...
# 4   The text describes the concept of forces and r...
# 5   Here's a summary of the text:\n\nThe rotating ...
# 6   The text appears to be a summary of the laws o...
# 7   The given text is a summary of Newton's Second...
# 8   The text explains Newton's third law of motion...
# 9   The text is a proof of the law of conservation...
# 10  The text appears to be a part of a science tex...
# 11  Summarized the text for you:\n\nThe text discu...
# 12  Here's a summary of the text:\n\nThe text disc...
# 13  To solve this problem, we can use the equation...
# 14  I'd be happy to summarize the text for you. Th...
# 15  The image depicts a simple illustration of a p...
# 16  The image shows a simple diagram of two masses...
# 17  This image depicts an astronaut in a white spa...
# 18  The image presents a table with three columns ...
# 19  The image presents a diagram illustrating the ...
# 20  The image shows two orange circles with text a...
# 21  The image is a blank white square with no visu...
# 22  The image presents a partial view of a table o...
# 23  The image depicts a cricket player in action, ...
# 24  The image presents a slide titled "Learning Ob...
# 25  The image presents a simple, text-based graphi...
# 26  The image depicts a sequence of orange circles...
# 27  The image presents a partial view of a graphic...
# 28  The image presents a simple, text-based graphi...
# 29  The image is a solid black rectangle, with no ...
# 30  The image presents a simple, yet distinctive d...
# 31  The image displays a partial word, with the le...
# 32  The image shows a simple diagram of a chemical...
# 33  The image presents a diagram of two circles wi...
# 34  The image depicts a QR code, a type of barcode...
# 35  The image shows a QR code with the text "K8ZFL...
# 36  The image depicts a QR code with a series of b...
# 37  The image depicts a simple, two-step process f...
# 38  The image presents a collage of three photogra...
# 39  The image is a cropped section of a larger gra...
# 40  The image is a blank white square with no visi...
# 41  The image depicts a silhouette of six people e...
# 42  The image depicts a simplified representation ...
# 43  The image depicts a roller coaster in motion, ...
# 44  The image shows a QR code with the text "XIZ91...
# 45  The image depicts two men working on a railroa...
# 46  The image depicts a mechanical system with a c...
# 47  The image presents a simple diagram featuring ...
# 48  The image depicts a diagram of the Earth and a...
# 49  The image shows two orange circles with black ...
# 50  The image presents a partial view of a graphic...
# 51  The image presents a simple diagram featuring ...
# 52  The image presents a detailed diagram of a hin...
# 53  The image depicts a partially visible orange c...
# 54  The image depicts a young girl rollerblading o...
