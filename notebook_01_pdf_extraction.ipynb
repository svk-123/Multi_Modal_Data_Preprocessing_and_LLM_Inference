# %% [markdown]
# ## **PDF extraction with Unstructured & Pandas**
#
# ### **1. Import Libraries**
# - Import required libraries for file handling, data processing, and PDF extraction.
#
# ### **2. Define Directories**
# - Set paths for PDFs, output files, and extracted images.
# - Create directories if they don’t exist.
#
# ### **3. Helper Functions**
# - `serialize_image()`: Convert image to base64 for storage.
# - `categorize_elements()`: Separate text and tables from extracted elements.
#
# ### **4. Process PDFs**
# - Use `partition_pdf()` to extract text, tables, and images.
# - Store extracted text and tables in a structured format.
# - Save images as base64-encoded strings.
#
# ### **5. Process All PDFs in Directory**
# - Iterate through all PDFs and process each file.
#
# ### **6. Save Extracted Data**
# - Convert extracted data into a Pandas DataFrame.
# - Save the DataFrame as a Parquet file for efficient storage.
#
# <span style="color:red;">### Issue: Extracts text in a multi-column PDF but after the first paragraph, it jumps to the first paragraph of the second column, instead of extracting the second paragraph from the first column.</span>

# %%
import os
import json
import pandas as pd
import base64
from unstructured.partition.pdf import partition_pdf
from unstructured.documents.elements import Table, Image, Title, NarrativeText
import unstructured.documents.elements
import pickle

# Define directories
pdf_dir = "./data/"
output_dir = "processed_output/"
image_dir = "./figures/"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)

#clear the files in the figures durectory
if os.path.isdir(image_dir):
    for filename in os.listdir(image_dir):
        file_path = os.path.join(image_dir, filename)
        if os.path.isfile(file_path):  # Only remove files
            os.remove(file_path)
    print(f"All files in {image_dir} have been deleted.")
else:
    print(f"{image_dir} is not a valid directory.")

# Pandas DataFrame storage
data_entries = []

# Function to serialize image to base64
def serialize_image(image_path):
    """Convert an image to a base64-encoded string."""
    with open(image_path, "rb") as img_file:
        img_bytes = img_file.read()
        return base64.b64encode(img_bytes).decode("utf-8")  # Convert bytes to UTF-8 string

def serialize_object(obj):
    """Serialize an object using pickle and encode it as a base64 string."""
    obj_bytes = pickle.dumps(obj)  # Convert object to bytes
    return base64.b64encode(obj_bytes).decode('utf-8')  # Encode as base64 string


def categorize_elements(raw_pdf_elements):
    """Categorize extracted elements into texts and tables."""
    texts = []
    tables = []
    for element in raw_pdf_elements:
        # Check if element is a Table
        if isinstance(element, unstructured.documents.elements.Table):
            tables.append(element)
        # Check if element is a text block (CompositeElement is a general parent class for text-like elements)
        elif isinstance(element, unstructured.documents.elements.CompositeElement):
            texts.append(element)
    return texts, tables

def process_pdf(pdf_path):
    pdf_name = os.path.basename(pdf_path)
    elements = partition_pdf(
        filename=pdf_path,
        strategy="hi_res",
        hi_res_model_name="yolox",
        infer_table_structure=True,
        extract_images_in_pdf=True,
        chunking_strategy="by_title",
        max_characters=4000,
        new_after_n_chars=3800,
        combine_text_under_n_chars=2000,
        image_output_dir_path=image_dir  # Storing images in the ./figures directory
    )

    # Categorize the elements into texts and tables
    texts, tables = categorize_elements(elements)

    # Process text elements
    for text in texts:
        entry = {"pdf_name": pdf_name, "element_type": "text", "content": text.text}
        data_entries.append(entry)

    # Process table elements
    for table in tables:
        entry = {"pdf_name": pdf_name, "element_type": "table", "content": serialize_object(table.to_dict())}
        data_entries.append(entry)

    # Process images in the ./figures directory
    for image_filename in os.listdir(image_dir):
        image_path = os.path.join(image_dir, image_filename)
        if image_filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):  # Filter for image files
            image_base64 = serialize_image(image_path)  # Convert the image to base64 string
            entry = {"pdf_name": pdf_name, "element_type": "image", "content": image_base64}
            data_entries.append(entry)

# ###--Uncomment for processing PDF again & save df----#####
# # Process all PDFs in the directory
# for pdf_file in os.listdir(pdf_dir):
#     if pdf_file.endswith(".pdf"):
#         pdf_path = os.path.join(pdf_dir, pdf_file)
#         print(f"Processing: {pdf_file}")
#         process_pdf(pdf_path)
#         #clear the files in the figures durectory
#         if os.path.isfile(image_dir):
#                 os.remove(image_dir)
            
# # Convert extracted data to a Pandas DataFrame
# df = pd.DataFrame(data_entries)
# # Save DataFrame to a Parquet file (efficient binary format)
# df.to_parquet(os.path.join(output_dir, "extracted_data_raw.parquet"), index=False)

print("Processing complete. Data saved in Pandas DataFrame!")
# Out:
# All files in ./figures/ have been deleted.
# Processing: Sample_Table.pdf
# Processing: chap_1_content.pdf
# Processing complete. Data saved in Pandas DataFrame!

# %%
import pandas as pd
# Load the Parquet file into a DataFrame
df = pd.read_parquet(os.path.join(output_dir, "extracted_data_raw.parquet"))
# Check the loaded DataFrame
df
# Out:
#               pdf_name element_type  \
# 0     Sample_Table.pdf        table
# 1   chap_1_content.pdf         text
# 2   chap_1_content.pdf         text
# 3   chap_1_content.pdf         text
# 4   chap_1_content.pdf         text
# 5   chap_1_content.pdf         text
# 6   chap_1_content.pdf         text
# 7   chap_1_content.pdf         text
# 8   chap_1_content.pdf         text
# 9   chap_1_content.pdf         text
# 10  chap_1_content.pdf         text
# 11  chap_1_content.pdf         text
# 12  chap_1_content.pdf         text
# 13  chap_1_content.pdf         text
# 14  chap_1_content.pdf         text
# 15  chap_1_content.pdf        image
# 16  chap_1_content.pdf        image
# 17  chap_1_content.pdf        image
# 18  chap_1_content.pdf        image
# 19  chap_1_content.pdf        image
# 20  chap_1_content.pdf        image
# 21  chap_1_content.pdf        image
# 22  chap_1_content.pdf        image
# 23  chap_1_content.pdf        image
# 24  chap_1_content.pdf        image
# 25  chap_1_content.pdf        image
# 26  chap_1_content.pdf        image
# 27  chap_1_content.pdf        image
# 28  chap_1_content.pdf        image
# 29  chap_1_content.pdf        image
# 30  chap_1_content.pdf        image
# 31  chap_1_content.pdf        image
# 32  chap_1_content.pdf        image
# 33  chap_1_content.pdf        image
# 34  chap_1_content.pdf        image
# 35  chap_1_content.pdf        image
# 36  chap_1_content.pdf        image
# 37  chap_1_content.pdf        image
# 38  chap_1_content.pdf        image
# 39  chap_1_content.pdf        image
# 40  chap_1_content.pdf        image
# 41  chap_1_content.pdf        image
# 42  chap_1_content.pdf        image
# 43  chap_1_content.pdf        image
# 44  chap_1_content.pdf        image
# 45  chap_1_content.pdf        image
# 46  chap_1_content.pdf        image
# 47  chap_1_content.pdf        image
# 48  chap_1_content.pdf        image
# 49  chap_1_content.pdf        image
# 50  chap_1_content.pdf        image
# 51  chap_1_content.pdf        image
# 52  chap_1_content.pdf        image
# 53  chap_1_content.pdf        image
# 54  chap_1_content.pdf        image
#
#                                               content
# 0   gASV6wIAAAAAAAB9lCiMBHR5cGWUjAVUYWJsZZSMCmVsZW...
# 1   1 www.tntextbooks.in LAWS OF MOTION\n\nLearnin...
# 2   in this unit.\n\n1\n\n| | 10th_Science_Unit-1....
# 3   1 .2 .1 T ypes of I nertia\n\na) Inertia of re...
# 4   forces.\n\n(a) Like parallel forces: Two or mo...
# 5   1 .4 .5 Rotating Effect of Force\n\nThe door c...
# 6   1 .4 .7 Application of T orque\n\n1. Gears:\n\...
# 7   1 .5 NE W T ON’ S S E C OND L A W OF MOT I ON\...
# 8   1 .7 NE W T ON’ S T H I R D L A W OF MOT I ON\...
# 9   Figure 1.7 Conservation of\n\nlinear momentum\...
# 10  1 .9 R OC K E T P R OP UL S I ON\n\nPropulsion...
# 11  R2\n\nAcceleration due to gravity\n\ng = GM --...
# 12  the gravity.\n\nWeight = Gravitational Force\n...
# 13  1 .1 2 .2 W eightlessness of the astronauts\n\...
# 14  Solution: Linear momentum = mass × velocity\n\...
# 15  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 16  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 17  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 18  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 19  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 21  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 22  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 23  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 24  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 25  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 26  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 27  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 28  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 29  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 30  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 31  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 32  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 33  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 34  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 35  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 36  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 37  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 38  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 39  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 40  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 41  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 42  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 43  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 44  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 45  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 46  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 47  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 48  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 49  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 50  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 51  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 52  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 53  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 54  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %% [markdown]
# # OpenAI Summarization and Image Analysis
#
# This notebook demonstrates how to use the OpenAI API to summarize text and analyze images within a DataFrame.
#
# ## Steps:
#
# 1. **Setup**:
#    - Load the OpenAI API key using `dotenv`.
#    - Initialize the `openai` client.
#
# 2. **Text Summarization**:
#    - `get_summary` function sends text to OpenAI's GPT-4 model for summarization.
#
# 3. **Image Analysis**:
#    - `analyze_image` function sends base64-encoded images to GPT-4 vision model (`gpt-4o`) for analysis.
#
# 4. **Apply Functions**:
#    - Summarization is applied to rows with `element_type == "text"`.
#    - Image analysis is applied to rows with `element_type == "image"`.
#
# 5. **Save and Display**:
#    - Save the processed DataFrame as a Parquet file.
#    - Print the DataFrame with summaries.
#
# <span style="color:red;">### Issue: How to summarize table input?</span>

# %%
import openai
import pandas as pd
import time
import os
from dotenv import load_dotenv
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

# Set up OpenAI client with your API key
client = openai.OpenAI(api_key=openai_api_key)

# Function to get summary from OpenAI API
def get_summary(text):
    try:
        response = client.chat.completions.create(
            model="gpt-4",  # Use "gpt-3.5-turbo" if needed
            messages=[
                {"role": "system", "content": "Summarize the following content concisely."},
                {"role": "user", "content": text}
            ],
            temperature=0.5,
            max_tokens=100
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error: {e}")
        return None
        
# Function to send base64 image to OpenAI API for analysis
def analyze_image(base64_image):
    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # Vision-enabled model
            messages=[
                {"role": "system", "content": "Analyze the image and describe its contents."},
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "What does this image contain?"},
                        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}}
                    ],
                },
            ],
            temperature=0.5,
            max_tokens=300
        )
        return response.choices[0].message.content.strip()  # Extract text response
    except Exception as e:
        print(f"Error: {e}")
        return None

# ###--Uncomment for openai processing again----#####
# def summarize_row(row):
#     if row["element_type"] == "text":
#         return get_summary(row["content"])
#     elif row["element_type"] == "image":
#         return analyze_image(row["content"])
#     elif row["element_type"] == "table":
#         # Table summarization: adjust the function if needed
#         return analyze_image(row["content"])
#     else:
#         return None

# df["summary"] = df.apply(summarize_row, axis=1)

# # Save DataFrame to a Parquet file (efficient binary format)
# df.to_parquet(os.path.join(output_dir, "extracted_data_summary.parquet"), index=False)

# %%
import pandas as pd
# Load the Parquet file into a DataFrame
df = pd.read_parquet(os.path.join(output_dir, "extracted_data_summary.parquet"))
# Check the loaded DataFrame
df
# Out:
#               pdf_name element_type  \
# 0     Sample_Table.pdf        table
# 1   chap_1_content.pdf         text
# 2   chap_1_content.pdf         text
# 3   chap_1_content.pdf         text
# 4   chap_1_content.pdf         text
# 5   chap_1_content.pdf         text
# 6   chap_1_content.pdf         text
# 7   chap_1_content.pdf         text
# 8   chap_1_content.pdf         text
# 9   chap_1_content.pdf         text
# 10  chap_1_content.pdf         text
# 11  chap_1_content.pdf         text
# 12  chap_1_content.pdf         text
# 13  chap_1_content.pdf         text
# 14  chap_1_content.pdf         text
# 15  chap_1_content.pdf        image
# 16  chap_1_content.pdf        image
# 17  chap_1_content.pdf        image
# 18  chap_1_content.pdf        image
# 19  chap_1_content.pdf        image
# 20  chap_1_content.pdf        image
# 21  chap_1_content.pdf        image
# 22  chap_1_content.pdf        image
# 23  chap_1_content.pdf        image
# 24  chap_1_content.pdf        image
# 25  chap_1_content.pdf        image
# 26  chap_1_content.pdf        image
# 27  chap_1_content.pdf        image
# 28  chap_1_content.pdf        image
# 29  chap_1_content.pdf        image
# 30  chap_1_content.pdf        image
# 31  chap_1_content.pdf        image
# 32  chap_1_content.pdf        image
# 33  chap_1_content.pdf        image
# 34  chap_1_content.pdf        image
# 35  chap_1_content.pdf        image
# 36  chap_1_content.pdf        image
# 37  chap_1_content.pdf        image
# 38  chap_1_content.pdf        image
# 39  chap_1_content.pdf        image
# 40  chap_1_content.pdf        image
# 41  chap_1_content.pdf        image
# 42  chap_1_content.pdf        image
# 43  chap_1_content.pdf        image
# 44  chap_1_content.pdf        image
# 45  chap_1_content.pdf        image
# 46  chap_1_content.pdf        image
# 47  chap_1_content.pdf        image
# 48  chap_1_content.pdf        image
# 49  chap_1_content.pdf        image
# 50  chap_1_content.pdf        image
# 51  chap_1_content.pdf        image
# 52  chap_1_content.pdf        image
# 53  chap_1_content.pdf        image
# 54  chap_1_content.pdf        image
#
#                                               content  \
# 0   gASV6wIAAAAAAAB9lCiMBHR5cGWUjAVUYWJsZZSMCmVsZW...
# 1   1 www.tntextbooks.in LAWS OF MOTION\n\nLearnin...
# 2   in this unit.\n\n1\n\n| | 10th_Science_Unit-1....
# 3   1 .2 .1 T ypes of I nertia\n\na) Inertia of re...
# 4   forces.\n\n(a) Like parallel forces: Two or mo...
# 5   1 .4 .5 Rotating Effect of Force\n\nThe door c...
# 6   1 .4 .7 Application of T orque\n\n1. Gears:\n\...
# 7   1 .5 NE W T ON’ S S E C OND L A W OF MOT I ON\...
# 8   1 .7 NE W T ON’ S T H I R D L A W OF MOT I ON\...
# 9   Figure 1.7 Conservation of\n\nlinear momentum\...
# 10  1 .9 R OC K E T P R OP UL S I ON\n\nPropulsion...
# 11  R2\n\nAcceleration due to gravity\n\ng = GM --...
# 12  the gravity.\n\nWeight = Gravitational Force\n...
# 13  1 .1 2 .2 W eightlessness of the astronauts\n\...
# 14  Solution: Linear momentum = mass × velocity\n\...
# 15  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 16  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 17  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 18  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 19  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 21  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 22  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 23  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 24  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 25  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 26  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 27  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 28  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 29  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 30  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 31  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 32  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 33  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 34  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 35  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 36  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 37  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 38  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 39  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 40  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 41  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 42  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 43  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 44  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 45  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 46  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 47  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 48  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 49  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 50  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 51  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 52  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 53  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 54  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                               summary
# 0                                                None
# 1   This lesson on the laws of motion aims to educ...
# 2   The content discusses the basics of mechanics,...
# 3   The text discusses different types of inertia:...
# 4   The text discusses different types of forces a...
# 5   The rotating effect of force is demonstrated w...
# 6   The application of torque can be seen in gears...
# 7   Newton's Second Law of Motion states that the ...
# 8   The content explains the concept of impulse an...
# 9   This passage describes the concept of conserva...
# 10  Rocket propulsion is based on the law of conse...
# 11  The text discusses the concept of acceleration...
# 12  The content discusses the concept of weight as...
# 13  Contrary to popular belief, astronauts in orbi...
# 14  The content discusses three physics problems a...
# 15  The image is a diagram of a person with arrows...
# 16  The image depicts a diagram of two masses, \( ...
# 17  The image shows an astronaut in a space suit f...
# 18  The image is a table illustrating the effects ...
# 19  The image depicts a physics diagram illustrati...
# 20  The image appears to be a diagram related to p...
# 21  The image is completely white and contains no ...
# 22  The image appears to contain a small portion o...
# 23  The image shows a cricket player in a fielding...
# 24  The image contains a list of learning objectiv...
# 25  The image shows a partial view of a text, spec...
# 26  The image depicts a physics diagram illustrati...
# 27  The image contains a partial view of text and ...
# 28  The image contains a partial view of text, spe...
# 29  The image is completely black and does not con...
# 30  The image contains the number ".7" written in ...
# 31  The image contains a partial view of text, spe...
# 32  The image shows a section of an illustration w...
# 33  The image contains two circles, each with a ho...
# 34  The image contains a QR code with the text "XF...
# 35  This image contains a QR code with the text "K...
# 36  The image contains a QR code with the text "IJ...
# 37  The image illustrates a simple physics experim...
# 38  The image is divided into three sections:\n\n1...
# 39  The image appears to contain a partial view of...
# 40  The image is completely blank, containing only...
# 41  The image shows a silhouette of several people...
# 42  The image contains a partial view of a diagram...
# 43  The image shows a group of people riding a rol...
# 44  The image contains a QR code with the text "XI...
# 45  The image shows two workers wearing orange saf...
# 46  The image depicts a hand applying force (F) to...
# 47  The image shows two circular objects labeled a...
# 48  The image is a diagram illustrating the gravit...
# 49  The image shows two circles labeled \(m_1\) an...
# 50  The image contains a partial view of an orange...
# 51  The image contains a diagram with two orange c...
# 52  The image contains two illustrations related t...
# 53  The image shows a partial view of an orange ci...
# 54  The image shows a child rollerblading outdoors...

# %% [markdown]
# ## Prepare QA from textbook QA page
# <span style="color:red;">### Issue: Does not extract the questions in multi-colum pdf correctly. Mixes the questions & answers string assuming a single column layout</span>

# %%
# Define directories
pdf_dir = "./data/QA"
output_dir = "processed_output/"
image_dir = "./figures/"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)

#clear the files in the figures durectory
if os.path.isdir(image_dir):
    for filename in os.listdir(image_dir):
        file_path = os.path.join(image_dir, filename)
        if os.path.isfile(file_path):  # Only remove files
            os.remove(file_path)
    print(f"All files in {image_dir} have been deleted.")
else:
    print(f"{image_dir} is not a valid directory.")

# Pandas DataFrame storage
data_entries = []

###--Uncomment for processing PDF again & save df----#####
# Process all PDFs in the directory
for pdf_file in os.listdir(pdf_dir):
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, pdf_file)
        print(f"Processing: {pdf_file}")
        process_pdf(pdf_path)
        #clear the files in the figures durectory
        if os.path.isfile(image_dir):
                os.remove(image_dir)
            
# Convert extracted data to a Pandas DataFrame
df_qa = pd.DataFrame(data_entries)
# Save DataFrame to a Parquet file (efficient binary format)
df_qa.to_parquet(os.path.join(output_dir, "extracted_data_qa.parquet"), index=False)

print("Processing complete. Data saved in Pandas DataFrame!")
# Out:
# All files in ./figures/ have been deleted.
# Processing: chap_1_QA.pdf
# Processing complete. Data saved in Pandas DataFrame!

# %%
df_qa
# Out:
#          pdf_name element_type  \
# 0   chap_1_QA.pdf         text
# 1   chap_1_QA.pdf         text
# 2   chap_1_QA.pdf         text
# 3   chap_1_QA.pdf         text
# 4   chap_1_QA.pdf        image
# 5   chap_1_QA.pdf        image
# 6   chap_1_QA.pdf        image
# 7   chap_1_QA.pdf        image
# 8   chap_1_QA.pdf        image
# 9   chap_1_QA.pdf        image
# 10  chap_1_QA.pdf        image
# 11  chap_1_QA.pdf        image
#
#                                               content
# 0   |\n\nTT\n\n&\n\nwww.tntextbooks.in\n\n@ iG\n\n...
# 1   handle.\n\n5. There is no gravity in the orbit...
# 2   VIII. Answer in detail.\n\nReason: ‘g’ depends...
# 3   ICT CORNER\n\nNewton’s second law\n\nSteps\n\n...
# 4   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 5   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 6   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 7   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 8   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 9   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 10  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 11  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %%
df_qa['content'].iloc[0]
# Out:
# '|\n\nTT\n\n&\n\nwww.tntextbooks.in\n\n@ iG\n\nT E X T B O O K E V A L U A T I O N\n\nI. Choose the correct answer\n\n1) Inertia of a body depends on\n\n9) If the Earth shrinks to 50% of its real radius its mass remaining the same, the weight of a body on the Earth will\n\na) weight of the object\n\nb) acceleration due to gravity of the planet\n\na) decrease by 50% b) increase by 50% c) decrease by 25% d) increase by 300%\n\nc) mass of the object\n\nd) Both a & b\n\n10) To project the rockets which of the follow- ing principle(s) is /(are) required?\n\n2) Impulse is equals to a) rate of change of momentum b) rate of force and time c) change of momentum d) rate of change of mass\n\na) Newton’s third law of motion b) Newton’s law of gravitation c) law of conservation of linear momentum d) both a and c\n\nII. Fill in the blanks\n\n3) Newton’s III law is applicable a) for a body is at rest b) for a body in motion c) both a & b\n\nc) both a & b\n\n1. To produce a displacement ___________\n\nis required\n\n2. Passengers lean forward when sudden brake is applied in a moving vehicle. This can be explained by ___________\n\nd) only for bodies with equal masses\n\n4) Plotting a graph for momentum on the Y-axis and time on X-axis. slope of momen- tum-time graph gives\n\n3. By convention, the clockwise moments are taken as ___________ and the anticlockwise moments are taken\n\nas__________\n\na) Impulsive force b) Acceleration\n\n4. ___________ is used to change the speed of car.\n\nc) Force d) Rate of force\n\n5) In which of the following sport the turning of effect of force used\n\n5. A man of mass 100 kg has a weight of ___________ at the surface of the Earth\n\na) swimming\n\nc) cycling\n\nb) tennis\n\nd) hockey\n\nIII. State whether the following statements are true or false. Correct the statement if it is false\n\n6) The unit of ‘g’ is m s-2. It can be also expressed as\n\na) cms-1\n\nb) Nkg-1\n\n1. The linear momentum of a system of particles is always conserved.\n\nc) Nm2kg-1\n\nd) cm2s-2\n\n7) One kilogram force equals to a) 9.8 dyne b) 9.8 × 104 N c) 98 × 104 dyne d) 980 dyne\n\n8) The mass of a body is measured on planet Earth as M kg. When it is taken to a planet of radius half that of the Earth then its value will be____kg\n\na) 4 M b) 2M c) M/4 d) M\n\n2. Apparent weight of a person is always equal to his actual weight\n\n3. Weight of a body is greater at the equator and less at the polar region.\n\n4. Turning a nut with a spanner having a short handle is so easy than one with a long'

# %% [markdown]
# ## Prepare QA from textbook QA page
# ### Split 2-column pdf into two pages

# %%
# from pdf2image import convert_from_path
# from PIL import Image
# from reportlab.pdfgen import canvas
# from reportlab.lib.pagesizes import letter

# # Path to your multi-column PDF
# pdf_path = './data/QA/chap_1_QA.pdf'

# # Convert PDF to images (one per page)
# pages = convert_from_path(pdf_path, 300)  # 300 DPI for better accuracy

# # List to hold new pages (images)
# new_pages = []

# # Process each page
# for page_number, page in enumerate(pages):
#     width, height = page.size
    
#     # Define the left and right halves of the page (vertically split)
#     left_half = page.crop((0, 0, width // 2, height))  # Left half
#     right_half = page.crop((width // 2, 0, width, height))  # Right half
    
#     # Save the left and right halves as separate new images
#     left_image_path = f"left_page_{page_number + 1}.png"
#     right_image_path = f"right_page_{page_number + 1}.png"
    
#     left_half.save(left_image_path)
#     right_half.save(right_image_path)
    
#     # Append image paths to new_pages (for later inclusion in PDF)
#     new_pages.append(left_image_path)
#     new_pages.append(right_image_path)

# # Create a new PDF with the new images (left and right halves)
# output_pdf_path = './data/QA/new_chap_1_QA.pdf'
# c = canvas.Canvas(output_pdf_path, pagesize=letter)

# for image_path in new_pages:
#     c.drawImage(image_path, 0, 0, width=400, height=600)  # Adjust the width/height as needed
#     c.showPage()  # Move to the next page

# c.save()

# print(f"New PDF saved at {output_pdf_path}")

# %% [markdown]
# ## Prepare QA from textbook QA page
# ### Extract using split pdf (questions and answers are more streamlined)

# %%
# Define directories
pdf_dir = "./data/QA_split"
output_dir = "processed_output/"
image_dir = "./figures/"
os.makedirs(output_dir, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)

#clear the files in the figures durectory
if os.path.isdir(image_dir):
    for filename in os.listdir(image_dir):
        file_path = os.path.join(image_dir, filename)
        if os.path.isfile(file_path):  # Only remove files
            os.remove(file_path)
    print(f"All files in {image_dir} have been deleted.")
else:
    print(f"{image_dir} is not a valid directory.")

# Pandas DataFrame storage
data_entries = []

###--Uncomment for processing PDF again & save df----#####
# Process all PDFs in the directory
for pdf_file in os.listdir(pdf_dir):
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, pdf_file)
        print(f"Processing: {pdf_file}")
        process_pdf(pdf_path)
        #clear the files in the figures durectory
        if os.path.isfile(image_dir):
                os.remove(image_dir)
            
# Convert extracted data to a Pandas DataFrame
df_qa_split = pd.DataFrame(data_entries)
# Save DataFrame to a Parquet file (efficient binary format)
df_qa_split.to_parquet(os.path.join(output_dir, "extracted_data_qa.parquet"), index=False)

print("Processing complete. Data saved in Pandas DataFrame!")
# Out:
# All files in ./figures/ have been deleted.
# Processing: new_chap_1_QA.pdf
# Processing complete. Data saved in Pandas DataFrame!

# %%
df_qa_split
# Out:
#             pdf_name element_type  \
# 0  new_chap_1_QA.pdf         text
# 1  new_chap_1_QA.pdf         text
# 2  new_chap_1_QA.pdf         text
# 3  new_chap_1_QA.pdf        image
# 4  new_chap_1_QA.pdf        image
# 5  new_chap_1_QA.pdf        image
# 6  new_chap_1_QA.pdf        image
#
#                                              content
# 0  J o_O\n\n4\n\nwww .tnte>\n\n\& TEXTBOOK EVALUA...
# 1  Laws of motion\n\ns2/s/2022 2:48:49 PM\n\nJ =\...
# 2  VIII. Answer in detail.\n\n1. What are the typ...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 5  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 6  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %%
df_qa_split['content'].iloc[0]
# Out:
# 'J o_O\n\n4\n\nwww .tnte>\n\n\\& TEXTBOOK EVALUATIO\n\nS\n\nI. Choose the correct answer 1) Inertia of a body depends on a) weight of the object b) acceleration due to gravity of the planet c) mass of the object d) Botha & b 2) Impulse is equals to a) rate of change of momentum b) rate of force and time c) change of momentum d) rate of change of mass 3) Newtons III law is applicable a) for a body is at rest b) for a body in motion c) botha &b d) only for bodies with equal masses 4) Plotting a graph for momentum on the Y-axis and time on X-axis. slope of momen- tum-time graph gives a) Impulsive force b) Acceleration c) Force d) Rate of force 5) In which of the following sport the turning of effect of force used a) swimming b) tennis c) cycling d) hockey 6) The unit of ‘g’ ism s*. It can be also expressed as a) cms! b) Nkg"! c) Nm’kg"! d) cm/’s? 7) One kilogram force equals to a) 9.8 dyne b) 9.8 x 10° N c) 98 x 10* dyne d) 980 dyne 8) The mass of a body is measured on planet Earth as M kg. When it is taken to a planet of radius half that of the Earth then its value will be kg a)4M b) 2M c) M/4 dM\n\n| | 1Oth_Science_Unit-1.indd 13\n\n@\n\n>\n\n<tbooks.in\n\n9) If the Earth shrinks to 50% of its real radius its mass remaining the same, the weight of a body on the Earth will\n\na) decrease by 50% b) increase by 50%\n\nc) decrease by 25% d) increase by 300%\n\nTo project the rockets which of the follow- ing principle(s) is /(are) required?\n\n10)\n\na) Newton\'s third law of motion\n\nb) Newton’s law of gravitation\n\nc) law of conservation of linear momentum\n\ndad) bothaandc\n\nIl. Fill in the blanks\n\n1. To produce a displacement is required\n\n2. Passengers lean forward when sudden brake is applied in a moving vehicle. This can be explained by ____\n\n3. By convention, the clockwise moments are taken as _ and the anticlockwise moments are taken aso\n\n4. is used to change the speed of car.\n\n5. A man of mass 100 kg has a weight of at the surface of the Earth\n\nIll. State whether the following statements are true or false. Correct the statement if it is false\n\n1. The linear momentum of a system of particles is always conserved.\n\nApparent weight of a person is always equal to his actual weight\n\n2.\n\nWeight of a body is greater at the equator and less at the polar region.\n\n3.\n\n4. Turning a nut with a spanner having a short handle is so easy than one with a long handle.\n\n5. There is no gravity in the orbiting space station around the Earth. So the astronauts feel weightlessness.'

# %% [markdown]
# ## Pass QA string to GPT and get QA in json format
# <span style="color:red;"> ### Issue: Further refinement required </span>

# %%
# Function to get summary from OpenAI API
def get_qa(text):
    """
    Uses the OpenAI API to extract questions and answers from the given text.
    The response is expected to be in JSON format, with keys like 'question', 
    'answer', and 'question_type'.
    """
    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # You can use "gpt-3.5-turbo" if needed
            messages=[
                {
                    "role": "system", 
                    "content": ("Prepare question and answer in JSON format. "
                                "Include keys for 'question', 'answer', and 'question_type'."
                                "Include a) b) c) d) options for multiple choice questions."
                                "if some key vales incomplete, fll with null so that I can read using python")
                },
                {"role": "user", "content": text}
            ],
            temperature=0.5,
            max_tokens=12000
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error: {e}")
        return None

def summarize_row(row):
    if row["element_type"] == "text":
        return get_qa(row["content"])
    # If you want to handle other element types (e.g., image or table), add additional logic here.
    return None

####--Uncomment for processing & save df----#####
# # Apply the function to extract Q&A in JSON format for text elements
# df_qa_split["summary"] = df_qa_split.apply(summarize_row, axis=1)
# # Save DataFrame to a Parquet file (efficient binary format)
# df_qa_split.to_parquet(os.path.join(output_dir, "extracted_data_qa.parquet"), index=False)

# %%
# Load the Parquet file into a DataFrame
df_qa_split = pd.read_parquet(os.path.join(output_dir, "extracted_data_qa.parquet"))
# Check the loaded DataFrame
df_qa_split
# Out:
#             pdf_name element_type  \
# 0  new_chap_1_QA.pdf         text
# 1  new_chap_1_QA.pdf         text
# 2  new_chap_1_QA.pdf         text
# 3  new_chap_1_QA.pdf        image
# 4  new_chap_1_QA.pdf        image
# 5  new_chap_1_QA.pdf        image
# 6  new_chap_1_QA.pdf        image
#
#                                              content  \
# 0  J o_O\n\n4\n\nwww .tnte>\n\n\& TEXTBOOK EVALUA...
# 1  Laws of motion\n\ns2/s/2022 2:48:49 PM\n\nJ =\...
# 2  VIII. Answer in detail.\n\n1. What are the typ...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 5  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 6  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                              summary
# 0  ```json\n{\n  "question_type": "multiple_choic...
# 1  ```json\n{\n  "question": "Match the following...
# 2  ```json\n{\n  "question": "What are the types ...
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None

# %%
import json

def extract_questions(json_str):
    """
    Given a JSON string containing a list of questions, 
    parse it into a DataFrame with selected columns.
    """
    try:
        # Clean up the JSON string by removing markdown code fences
        cleaned_str = json_str.strip()
        if cleaned_str.startswith("```json"):
            cleaned_str = cleaned_str.replace("```json", "", 1)
        if cleaned_str.endswith("```"):
            cleaned_str = cleaned_str[:-3]
        
        # Wrap the objects in square brackets if they're not already
        cleaned_str = cleaned_str.strip()
        if not (cleaned_str.startswith("[") and cleaned_str.endswith("]")):
            cleaned_str = f"[{cleaned_str}]"
        
        # Parse the JSON string
        data = json.loads(cleaned_str)
        df_q = pd.DataFrame(data)
        # Select the desired columns
        df_q = df_q[['question_type', 'question', 'answer', 'options']]
        return df_q
    except Exception as e:
        print(f"Error parsing JSON: {e}")
        # Return an empty DataFrame with the correct columns for consistency
        return pd.DataFrame(columns=['question_type', 'question', 'answer', 'options'])

# Apply the function to every row in the 'summary' column of df_qa_split.
# This returns a Series of DataFrames.
question_dfs = df_qa_split['summary'].apply(extract_questions)

# Combine all individual DataFrames into one
combined_questions_df = pd.concat(question_dfs.tolist(), ignore_index=True)
combined_questions_df
# Out:
# Error parsing JSON: 'NoneType' object has no attribute 'strip'
# Error parsing JSON: 'NoneType' object has no attribute 'strip'
# Error parsing JSON: 'NoneType' object has no attribute 'strip'
# Error parsing JSON: 'NoneType' object has no attribute 'strip'
#           question_type                                           question  \
# 0       multiple_choice                    1) Inertia of a body depends on
# 1       multiple_choice                            2) Impulse is equals to
# 2       multiple_choice                  3) Newton's III law is applicable
# 3       multiple_choice  4) Plotting a graph for momentum on the Y-axis...
# 4       multiple_choice  5) In which of the following sport the turning...
# 5       multiple_choice  6) The unit of ‘g’ is m/s². It can be also exp...
# 6       multiple_choice                    7) One kilogram force equals to
# 7       multiple_choice  8) The mass of a body is measured on planet Ea...
# 8       multiple_choice  9) If the Earth shrinks to 50% of its real rad...
# 9       multiple_choice  10) To project the rockets which of the follow...
# 10             matching  Match the following laws of motion with their ...
# 11  assertion_reasoning  Assertion & Reasoning: The sum of the clockwis...
# 12  assertion_reasoning  Assertion & Reasoning: The value of ‘g’ decrea...
# 13         short_answer           Define inertia. Give its classification.
# 14         short_answer  Classify the types of force based on their app...
# 15         short_answer  If a 5N and a 15N forces are acting opposite t...
# 16         short_answer                     Differentiate mass and weight.
# 17         short_answer                         Define moment of a couple.
# 18         short_answer                    State the principle of moments.
# 19         short_answer                         State Newton’s second law.
# 20         short_answer  Why is a spanner with a long handle preferred ...
# 21         short_answer  While catching a cricket ball the fielder lowe...
# 22         short_answer    How does an astronaut float in a space shuttle?
# 23      problem_solving  Two bodies have a mass ratio of 3:4. The force...
# 24      problem_solving  A ball of mass 1 kg moving with a speed of 10 ...
# 25      problem_solving  A mechanic unscrews a nut by applying a force ...
# 26      problem_solving  The ratio of masses of two planets is 2:3 and ...
# 27      detailed_answer  What are the types of inertia? Give an example...
# 28      detailed_answer                     State Newton’s laws of motion.
# 29      detailed_answer  Deduce the equation of a force using Newton’s ...
# 30      detailed_answer  State and prove the law of conservation of lin...
# 31      detailed_answer                        Describe rocket propulsion.
# 32      detailed_answer  State the universal law of gravitation and der...
# 33      detailed_answer  Give the applications of universal law gravita...
# 34            numerical  Two blocks of masses 8 kg and 2 kg respectivel...
# 35            numerical  A heavy truck and bike are moving with the sam...
# 36      detailed_answer  “Wearing helmet and fastening the seat belt is...
#
#                                                answer  \
# 0                                                   c
# 1                                                   c
# 2                                                   c
# 3                                                   c
# 4                                                   c
# 5                                                   b
# 6                                                   b
# 7                                                   d
# 8                                                   d
# 9                                                   d
# 10  {'a': 'Newton’s I law - Stable equilibrium of ...
# 11                                                  b
# 12                                                  c
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27  There are three types of inertia: 1. Inertia o...
# 28  Newton's First Law: An object remains at rest ...
# 29  According to Newton's second law of motion, th...
# 30  The law of conservation of linear momentum sta...
# 31  Rocket propulsion is based on Newton's third l...
# 32  The universal law of gravitation states that e...
# 33  The universal law of gravitation has several a...
# 34         The force exerted on the 2 kg mass is 3 N.
# 35                 The ratio of their momenta is 2:1.
# 36  Wearing a helmet and fastening the seat belt a...
#
#                                               options
# 0   {'a': 'weight of the object', 'b': 'accelerati...
# 1   {'a': 'rate of change of momentum', 'b': 'rate...
# 2   {'a': 'for a body is at rest', 'b': 'for a bod...
# 3   {'a': 'Impulsive force', 'b': 'Acceleration', ...
# 4   {'a': 'swimming', 'b': 'tennis', 'c': 'cycling...
# 5   {'a': 'cm/s²', 'b': 'N/kg', 'c': 'Nm/kg', 'd':...
# 6   {'a': '9.8 dyne', 'b': '9.8 x 10³ N', 'c': '98...
# 7        {'a': '4M', 'b': '2M', 'c': 'M/4', 'd': 'M'}
# 8   {'a': 'decrease by 50%', 'b': 'increase by 50%...
# 9   {'a': 'Newton's third law of motion', 'b': 'Ne...
# 10                                               None
# 11  {'a': 'If both the assertion and the reason ar...
# 12  {'a': 'If both the assertion and the reason ar...
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None

# %% [markdown]
# ### Here, we have extracted PDFs chapter & QA separately. The extracted contents are stored in dfs. Next we load this context (context) & qa (prompt) dfs & further perform Vector Search, RAG, & Inference.
